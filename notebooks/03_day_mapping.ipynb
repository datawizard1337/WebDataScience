# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None
# %matplotlib inline
sns.set_style("ticks")

# %% [markdown]
# # 4. GeoPandas

# %% [markdown]
# We will use GeoPandas to create maps. GeoPandas is an open source project to make working with geospatial data in Python easier. GeoPandas extends the dataypes used by pandas to allow spatial operations on geometric types. Let's install GeoPandas. This can be a little tricky. Sometimes it works with pip as we know it:

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\jan\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\jan\appdata\roaming\python\python37\site-packages (from geopandas) (1.2.2)
# Requirement already satisfied: fiona in c:\users\jan\anaconda3\lib\site-packages (from geopandas) (1.8.18)
# Requirement already satisfied: shapely in c:\users\jan\anaconda3\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\jan\anaconda3\lib\site-packages (from geopandas) (3.0.0.post1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jan\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jan\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\jan\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (1.20.1)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.1)
# Requirement already satisfied: click<8,>=4.0 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: gdal~=3.1.2 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (3.1.4)
# Requirement already satisfied: certifi in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (2020.12.5)
# Requirement already satisfied: six>=1.7 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied: munch in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in c:\users\jan\anaconda3\lib\site-packages (from fiona->geopandas) (19.3.0)

# %% [markdown]
# If this is **not** working, try the following:

# %%
# !pip install wheel
# !pip install pipwin
# !pipwin install shapely
# !pipwin install gdal
# !pipwin install -Iv fiona==1.8.14
# !pipwin install pyproj
# !pipwin install six
# !pipwin install rtree
# !pipwin install geopandas
# !pipwin install descartes
# !pip install mapclassify

# %% [markdown]
# Now we should be able to import geopandas:

# %%
import geopandas as gpd

# %% [markdown]
# Now we can use geopandas to read geodata (files that contain tabular data and geometry). The most common filetypes are:
# - **ESRI shapefile**: ESRI is "the Microsoft of Geographic Information Systems" and shapefiles are their standard file format. A shapefile consists of several files (3 to 5) but you want to work with the .shp file.
# - **Google KML/KMZ**: .kml and .kmz files are used by Google Maps and Google Earth.
# - **GeoJSON**: A open data format for geodata based on the popular JSON format.

# %% [markdown]
# Let's read in a GeoJSON file I prepared for us. You can see that it looks very much like a normal dataframe after loading.

# %%
gpd.read_file("world_map.json")
# Out:
#      scalerank       featurecla  labelrank                sovereignt sov_a3  \
# 0            1  Admin-0 country          2  United States of America    US1
# 1            1  Admin-0 country          2                    Canada    CAN
# 2            1  Admin-0 country          6                    Belize    BLZ
# 3            1  Admin-0 country          4               The Bahamas    BHS
# 4            1  Admin-0 country          5                Costa Rica    CRI
# ..         ...              ...        ...                       ...    ...
# 170          1  Admin-0 country          3                    Poland    POL
# 171          1  Admin-0 country          3                    Sweden    SWE
# 172          1  Admin-0 country          6                  Slovenia    SVN
# 173          1  Admin-0 country          2                    Russia    RUS
# 174          1  Admin-0 country          3                   Ukraine    UKR
#
#      adm0_dif  level               type                     admin adm0_a3  \
# 0           1      2            Country  United States of America     USA
# 1           0      2  Sovereign country                    Canada     CAN
# 2           0      2  Sovereign country                    Belize     BLZ
# 3           0      2  Sovereign country               The Bahamas     BHS
# 4           0      2  Sovereign country                Costa Rica     CRI
# ..        ...    ...                ...                       ...     ...
# 170         0      2  Sovereign country                    Poland     POL
# 171         0      2  Sovereign country                    Sweden     SWE
# 172         0      2  Sovereign country                  Slovenia     SVN
# 173         0      2  Sovereign country                    Russia     RUS
# 174         0      2  Sovereign country                   Ukraine     UKR
#
#      geou_dif                   geounit gu_a3  su_dif  \
# 0           0  United States of America   USA       0
# 1           0                    Canada   CAN       0
# 2           0                    Belize   BLZ       0
# 3           0               The Bahamas   BHS       0
# 4           0                Costa Rica   CRI       0
# ..        ...                       ...   ...     ...
# 170         0                    Poland   POL       0
# 171         0                    Sweden   SWE       0
# 172         0                  Slovenia   SVN       0
# 173         0                    Russia   RUS       0
# 174         0                   Ukraine   UKR       0
#
#                       subunit su_a3  brk_diff           name  \
# 0    United States of America   USA         0  United States
# 1                      Canada   CAN         0         Canada
# 2                      Belize   BLZ         0         Belize
# 3                 The Bahamas   BHS         0        Bahamas
# 4                  Costa Rica   CRI         0     Costa Rica
# ..                        ...   ...       ...            ...
# 170                    Poland   POL         0         Poland
# 171                    Sweden   SWE         0         Sweden
# 172                  Slovenia   SVN         0       Slovenia
# 173                    Russia   RUS         0         Russia
# 174                   Ukraine   UKR         0        Ukraine
#
#               name_long brk_a3       brk_name brk_group  abbrev postal  \
# 0         United States    USA  United States      None  U.S.A.     US
# 1                Canada    CAN         Canada      None    Can.     CA
# 2                Belize    BLZ         Belize      None  Belize     BZ
# 3               Bahamas    BHS        Bahamas      None    Bhs.     BS
# 4            Costa Rica    CRI     Costa Rica      None    C.R.     CR
# ..                  ...    ...            ...       ...     ...    ...
# 170              Poland    POL         Poland      None    Pol.     PL
# 171              Sweden    SWE         Sweden      None    Swe.      S
# 172            Slovenia    SVN       Slovenia      None    Slo.    SLO
# 173  Russian Federation    RUS         Russia      None    Rus.    RUS
# 174             Ukraine    UKR        Ukraine      None    Ukr.     UA
#
#                        formal_en formal_fr note_adm0 note_brk  \
# 0       United States of America      None      None     None
# 1                         Canada      None      None     None
# 2                         Belize      None      None     None
# 3    Commonwealth of the Bahamas      None      None     None
# 4         Republic of Costa Rica      None      None     None
# ..                           ...       ...       ...      ...
# 170           Republic of Poland      None      None     None
# 171            Kingdom of Sweden      None      None     None
# 172         Republic of Slovenia      None      None     None
# 173           Russian Federation      None      None     None
# 174                      Ukraine      None      None     None
#
#                     name_sort name_alt  mapcolor7  mapcolor8  mapcolor9  \
# 0    United States of America     None          4          5          1
# 1                      Canada     None          6          6          2
# 2                      Belize     None          1          4          5
# 3                Bahamas, The     None          1          1          2
# 4                  Costa Rica     None          3          2          4
# ..                        ...      ...        ...        ...        ...
# 170                    Poland     None          3          7          1
# 171                    Sweden     None          1          4          2
# 172                  Slovenia     None          2          3          2
# 173        Russian Federation     None          2          5          7
# 174                   Ukraine     None          5          1          6
#
#      mapcolor13    pop_est  gdp_md_est  pop_year  lastcensus  gdp_year  \
# 0             1  313973000  15094000.0         0        2010         0
# 1             2   33487208   1300000.0       -99        2011       -99
# 2             7     307899      2536.0       -99        2010       -99
# 3             5     309156      9093.0       -99        2010       -99
# 4             2    4253877     48320.0       -99        2011       -99
# ..          ...        ...         ...       ...         ...       ...
# 170           2   38482919    667900.0       -99        2011       -99
# 171           4    9059651    344300.0       -99         -99       -99
# 172          12    2005692     59340.0       -99        2011       -99
# 173           7  140041247   2266000.0       -99        2010       -99
# 174           3   45700395    339800.0       -99        2001       -99
#
#                         economy               income_grp  wikipedia fips_10  \
# 0       1. Developed region: G7     1. High income: OECD          0    None
# 1       1. Developed region: G7     1. High income: OECD        -99    None
# 2          6. Developing region   4. Lower middle income        -99    None
# 3          6. Developing region  2. High income: nonOECD        -99    None
# 4       5. Emerging region: G20   3. Upper middle income        -99    None
# ..                          ...                      ...        ...     ...
# 170  2. Developed region: nonG7     1. High income: OECD        -99    None
# 171  2. Developed region: nonG7     1. High income: OECD        -99    None
# 172  2. Developed region: nonG7     1. High income: OECD        -99    None
# 173    3. Emerging region: BRIC   3. Upper middle income        -99    None
# 174        6. Developing region   4. Lower middle income        -99    None
#
#     iso_a2 iso_a3 iso_n3 un_a3 wb_a2 wb_a3  woe_id adm0_a3_is adm0_a3_us  \
# 0       US    USA    840   840    US   USA     -99        USA        USA
# 1       CA    CAN    124   124    CA   CAN     -99        CAN        CAN
# 2       BZ    BLZ    084   084    BZ   BLZ     -99        BLZ        BLZ
# 3       BS    BHS    044   044    BS   BHS     -99        BHS        BHS
# 4       CR    CRI    188   188    CR   CRI     -99        CRI        CRI
# ..     ...    ...    ...   ...   ...   ...     ...        ...        ...
# 170     PL    POL    616   616    PL   POL     -99        POL        POL
# 171     SE    SWE    752   752    SE   SWE     -99        SWE        SWE
# 172     SI    SVN    705   705    SI   SVN     -99        SVN        SVN
# 173     RU    RUS    643   643    RU   RUS     -99        RUS        RUS
# 174     UA    UKR    804   804    UA   UKR     -99        UKR        UKR
#
#      adm0_a3_un  adm0_a3_wb      continent region_un         subregion  \
# 0           -99         -99  North America  Americas  Northern America
# 1           -99         -99  North America  Americas  Northern America
# 2           -99         -99  North America  Americas   Central America
# 3           -99         -99  North America  Americas         Caribbean
# 4           -99         -99  North America  Americas   Central America
# ..          ...         ...            ...       ...               ...
# 170         -99         -99         Europe    Europe    Eastern Europe
# 171         -99         -99         Europe    Europe   Northern Europe
# 172         -99         -99         Europe    Europe   Southern Europe
# 173         -99         -99         Europe    Europe    Eastern Europe
# 174         -99         -99         Europe    Europe    Eastern Europe
#
#                      region_wb  name_len  long_len  abbrev_len  tiny  \
# 0                North America        13        13           6   -99
# 1                North America         6         6           4   -99
# 2    Latin America & Caribbean         6         6           6   -99
# 3    Latin America & Caribbean         7         7           4   -99
# 4    Latin America & Caribbean        10        10           4   -99
# ..                         ...       ...       ...         ...   ...
# 170      Europe & Central Asia         6         6           4   -99
# 171      Europe & Central Asia         6         6           4   -99
# 172      Europe & Central Asia         8         8           4   -99
# 173      Europe & Central Asia         6        18           4   -99
# 174      Europe & Central Asia         7         7           4   -99
#
#      homepart     filename                                           geometry
# 0           1  USA.geojson  MULTIPOLYGON (((-155.542 19.083, -155.688 18.9...
# 1           1  CAN.geojson  MULTIPOLYGON (((-63.664 46.550, -62.939 46.416...
# 2           1  BLZ.geojson  POLYGON ((-89.143 17.808, -89.151 17.955, -89....
# 3           1  BHS.geojson  MULTIPOLYGON (((-77.535 23.760, -77.780 23.710...
# 4           1  CRI.geojson  POLYGON ((-82.966 8.225, -83.508 8.447, -83.71...
# ..        ...          ...                                                ...
# 170         1  POL.geojson  POLYGON ((15.017 51.107, 14.607 51.745, 14.685...
# 171         1  SWE.geojson  POLYGON ((22.183 65.724, 21.214 65.026, 21.370...
# 172         1  SVN.geojson  POLYGON ((13.806 46.509, 14.632 46.432, 15.137...
# 173         1  RUS.geojson  MULTIPOLYGON (((143.648 50.748, 144.654 48.976...
# 174         1  UKR.geojson  POLYGON ((31.786 52.102, 32.159 52.061, 32.412...
#
# [175 rows x 65 columns]

# %% [markdown]
# Let's have a look at the datatypes of this dataframe. There are quite a lot of columns. The interesting one is the last one though. It is named "geometry" and has our new dataframe datatype "geometry".

# %%
world_map = gpd.read_file("world_map.json")
world_map.dtypes
# Out:
# scalerank        int64
# featurecla      object
# labelrank        int64
# sovereignt      object
# sov_a3          object
# adm0_dif         int64
# level            int64
# type            object
# admin           object
# adm0_a3         object
# geou_dif         int64
# geounit         object
# gu_a3           object
# su_dif           int64
# subunit         object
# su_a3           object
# brk_diff         int64
# name            object
# name_long       object
# brk_a3          object
# brk_name        object
# brk_group       object
# abbrev          object
# postal          object
# formal_en       object
# formal_fr       object
# note_adm0       object
# note_brk        object
# name_sort       object
# name_alt        object
# mapcolor7        int64
# mapcolor8        int64
# mapcolor9        int64
# mapcolor13       int64
# pop_est          int64
# gdp_md_est     float64
# pop_year         int64
# lastcensus       int64
# gdp_year         int64
# economy         object
# income_grp      object
# wikipedia        int64
# fips_10         object
# iso_a2          object
# iso_a3          object
# iso_n3          object
# un_a3           object
# wb_a2           object
# wb_a3           object
# woe_id           int64
# adm0_a3_is      object
# adm0_a3_us      object
# adm0_a3_un       int64
# adm0_a3_wb       int64
# continent       object
# region_un       object
# subregion       object
# region_wb       object
# name_len         int64
# long_len         int64
# abbrev_len       int64
# tiny             int64
# homepart         int64
# filename        object
# geometry      geometry
# dtype: object

# %% [markdown]
# The geometry stored in this column allows us to plot the dataframe as a map.

# %%
world_map.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
world_map.head(1)
# Out:
#    scalerank       featurecla  labelrank                sovereignt sov_a3  \
# 0          1  Admin-0 country          2  United States of America    US1
#
#    adm0_dif  level     type                     admin adm0_a3  geou_dif  \
# 0         1      2  Country  United States of America     USA         0
#
#                     geounit gu_a3  su_dif                   subunit su_a3  \
# 0  United States of America   USA       0  United States of America   USA
#
#    brk_diff           name      name_long brk_a3       brk_name brk_group  \
# 0         0  United States  United States    USA  United States      None
#
#    abbrev postal                 formal_en formal_fr note_adm0 note_brk  \
# 0  U.S.A.     US  United States of America      None      None     None
#
#                   name_sort name_alt  mapcolor7  mapcolor8  mapcolor9  \
# 0  United States of America     None          4          5          1
#
#    mapcolor13    pop_est  gdp_md_est  pop_year  lastcensus  gdp_year  \
# 0           1  313973000  15094000.0         0        2010         0
#
#                    economy            income_grp  wikipedia fips_10 iso_a2  \
# 0  1. Developed region: G7  1. High income: OECD          0    None     US
#
#   iso_a3 iso_n3 un_a3 wb_a2 wb_a3  woe_id adm0_a3_is adm0_a3_us  adm0_a3_un  \
# 0    USA    840   840    US   USA     -99        USA        USA         -99
#
#    adm0_a3_wb      continent region_un         subregion      region_wb  \
# 0         -99  North America  Americas  Northern America  North America
#
#    name_len  long_len  abbrev_len  tiny  homepart     filename  \
# 0        13        13           6   -99         1  USA.geojson
#
#                                             geometry
# 0  MULTIPOLYGON (((-155.54211 19.08348, -155.6881...

# %%
world_map.head(1)["geometry"]
# Out:
# 0    MULTIPOLYGON (((-155.54211 19.08348, -155.6881...
# Name: geometry, dtype: geometry

# %% [markdown]
# If we want to plot a single observation from our geopandas dataframe (corresponding to a single country), we can simply filter that observation and plot it.

# %%
world_map[world_map["sovereignt"] == "Germany"].plot()
# Out:
# <AxesSubplot:>

# %%
world_map.head(1)
# Out:
#    scalerank       featurecla  labelrank                sovereignt sov_a3  \
# 0          1  Admin-0 country          2  United States of America    US1
#
#    adm0_dif  level     type                     admin adm0_a3  geou_dif  \
# 0         1      2  Country  United States of America     USA         0
#
#                     geounit gu_a3  su_dif                   subunit su_a3  \
# 0  United States of America   USA       0  United States of America   USA
#
#    brk_diff           name      name_long brk_a3       brk_name brk_group  \
# 0         0  United States  United States    USA  United States      None
#
#    abbrev postal                 formal_en formal_fr note_adm0 note_brk  \
# 0  U.S.A.     US  United States of America      None      None     None
#
#                   name_sort name_alt  mapcolor7  mapcolor8  mapcolor9  \
# 0  United States of America     None          4          5          1
#
#    mapcolor13    pop_est  gdp_md_est  pop_year  lastcensus  gdp_year  \
# 0           1  313973000  15094000.0         0        2010         0
#
#                    economy            income_grp  wikipedia fips_10 iso_a2  \
# 0  1. Developed region: G7  1. High income: OECD          0    None     US
#
#   iso_a3 iso_n3 un_a3 wb_a2 wb_a3  woe_id adm0_a3_is adm0_a3_us  adm0_a3_un  \
# 0    USA    840   840    US   USA     -99        USA        USA         -99
#
#    adm0_a3_wb      continent region_un         subregion      region_wb  \
# 0         -99  North America  Americas  Northern America  North America
#
#    name_len  long_len  abbrev_len  tiny  homepart     filename  \
# 0        13        13           6   -99         1  USA.geojson
#
#                                             geometry
# 0  MULTIPOLYGON (((-155.54211 19.08348, -155.6881...

# %% [markdown]
# We can also select several observations and plot them.

# %%
world_map[world_map["subregion"] == "Northern America"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Choropleth maps

# %% [markdown]
# We may pass a certain column which we want to use for coloring of the countries (creating a so-called choropleth map https://en.wikipedia.org/wiki/Choropleth_map).

# %%
world_map.plot(figsize=(20,20), column="pop_est")
# Out:
# <AxesSubplot:>

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
world_map["pop_est"].describe()
# Out:
# count          175.000
# mean      38711381.977
# std      138187459.009
# min            -99.000
# 25%        3497191.000
# 50%        9059651.000
# 75%       26380531.500
# max     1338612970.000
# Name: pop_est, dtype: float64

# %%
world_map[world_map["pop_est"] == world_map["pop_est"].max()]
# Out:
#     scalerank       featurecla  labelrank sovereignt sov_a3  adm0_dif  level  \
# 37          1  Admin-0 country          2      China    CH1         1      2
#
#        type  admin adm0_a3  geou_dif geounit gu_a3  su_dif subunit su_a3  \
# 37  Country  China     CHN         0   China   CHN       0   China   CHN
#
#     brk_diff   name name_long brk_a3 brk_name brk_group abbrev postal  \
# 37         0  China     China    CHN    China      None  China     CN
#
#                      formal_en formal_fr note_adm0 note_brk name_sort  \
# 37  People's Republic of China      None      None     None     China
#
#    name_alt  mapcolor7  mapcolor8  mapcolor9  mapcolor13     pop_est  \
# 37     None          4          4          4           3  1338612970
#
#     gdp_md_est  pop_year  lastcensus  gdp_year                   economy  \
# 37 7973000.000       -99        2010       -99  3. Emerging region: BRIC
#
#                 income_grp  wikipedia fips_10 iso_a2 iso_a3 iso_n3 un_a3  \
# 37  3. Upper middle income        -99    None     CN    CHN    156   156
#
#    wb_a2 wb_a3  woe_id adm0_a3_is adm0_a3_us  adm0_a3_un  adm0_a3_wb  \
# 37    CN   CHN     -99        CHN        CHN         -99         -99
#
#    continent region_un     subregion            region_wb  name_len  long_len  \
# 37      Asia      Asia  Eastern Asia  East Asia & Pacific         5         5
#
#     abbrev_len  tiny  homepart     filename  \
# 37           5   -99         1  CHN.geojson
#
#                                              geometry
# 37  MULTIPOLYGON (((110.33919 18.67840, 109.47521 ...

# %% [markdown]
# The classes used to color the countries are not that informative, as most countries are in the lowest (darkest) class. We can change that by selecting a more appropriate choropleth classification scheme. Here are some commonly used ones:
# - 'NaturalBreaks' https://en.wikipedia.org/wiki/Jenks_natural_breaks_optimization
# - 'Quantiles' https://en.wikipedia.org/wiki/Quantile
# - 'Percentiles' https://en.wikipedia.org/wiki/Percentile
# - 'StdMean' https://en.wikipedia.org/wiki/Standard_deviation
#
# We may also pass a ```k=``` parameter to define the number of classes we want to create using the defined scheme. We also want a legend for our map which we can achieve by passing ```legend=True```.

# %%
world_map.plot(figsize=(20,20), column="pop_est", scheme="Quantiles", k=10, legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the legend, we can see that the lowest value for population is "-99", which makes no sense. It seems like that the person who created this dataset used "-99" to mark missing values. Let's replace them.

# %%
world_map["pop_est"] = world_map["pop_est"].replace({0: np.nan})

# %% [markdown]
# Let's also create a new column containing the population in millions.

# %%
world_map["pop_million"] = world_map["pop_est"] / 1000000

# %% [markdown]
# We can also pass some ```missing_kwds={}``` to tell geopandas how to handle missing data.

# %%
world_map.plot(figsize=(20,20), column="pop_million", scheme="NaturalBreaks", k=5, legend=True, missing_kwds={'color': 'grey', "label": "Missing"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# To make some proper maps, we usually want to use the matplotlib approach we learned about last week.

# %%
from matplotlib import gridspec

# create one figure size 20,10
fig = plt.figure(figsize=(20,10))
# use the gridspec function to define 2 columns in this figure; set the width ratio to 3:1, meaning the first column will be 3 times the width of the second column
columns = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[3, 1])

# add a subplot to the first column of the figure
axis_0 = fig.add_subplot(columns[0])
# world population choropleth map
world_map.plot(column="pop_million", scheme="NaturalBreaks", k=5, legend=True,
               legend_kwds={"loc": "lower left"},
               missing_kwds={'color': 'lightgrey', "label": "Missing"},
               ax=axis_0)
axis_0.set_axis_off()


# add a subplot to the second column of the figure
axis_1 = fig.add_subplot(columns[1])
# world population histogram
sns.distplot(world_map["pop_million"], kde=False, bins=50, ax=axis_1)
axis_1.set_xlabel("Population in Millions")
axis_1.set_ylabel("Frequency")
axis_1.set_xlim(0,1500)


# Final adjustments
fig.tight_layout() #tidy up the figure 
plt.savefig("world_population.png", dpi=150) #save the figure

# %% [markdown]
# Remember the nice color palettes from seaborn? --> https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.palplot(sns.color_palette("Paired"))

# %% [markdown]
# We can also get the color hex codes for these colors using the ```as_hex()``` method on the palette.

# %%
sns.color_palette("Paired").as_hex()
# Out:
# ['#a6cee3',
#  '#1f78b4',
#  '#b2df8a',
#  '#33a02c',
#  '#fb9a99',
#  '#e31a1c',
#  '#fdbf6f',
#  '#ff7f00',
#  '#cab2d6',
#  '#6a3d9a',
#  '#ffff99',
#  '#b15928']

# %% [markdown]
# If we want to use one these in geopandas, we have to transfer the seaborn color palette hex codes to a matplotlib (listed) colormap.

# %%
from matplotlib.colors import ListedColormap

sns_color_palette = ListedColormap(sns.color_palette("Paired").as_hex())

# %% [markdown]
# Let's update the map we have created above with some more beautiful seaborn colors. For the histogram, we can select the second color of the palette directly.

# %%
# create one figure size 20,10
fig = plt.figure(figsize=(20,10))
# use the gridspec function to define 2 columns in this figure; set the width ratio to 3:1, meaning the first column will be 3 times the width of the second column
columns = gridspec.GridSpec(ncols=2, nrows=1, width_ratios=[3, 1])

# add a subplot to the first column of the figure
axis_0 = fig.add_subplot(columns[0])
# world population choropleth map
world_map.plot(column="pop_million", scheme="NaturalBreaks", k=5, legend=True, cmap=sns_color_palette,
               legend_kwds={"loc": "lower left", },
               missing_kwds={'color': 'lightgrey', "label": "Missing"},
               ax=axis_0)
axis_0.set_axis_off()


# add a subplot to the second column of the figure
axis_1 = fig.add_subplot(columns[1])
# world population histogram
sns.distplot(world_map["pop_million"], kde=False, bins=50, ax=axis_1, color=sns.color_palette("Paired")[4])
axis_1.set_xlabel("Population in Millions")
axis_1.set_ylabel("Frequency")
axis_1.set_xlim(0,1500)


# Final adjustments
fig.tight_layout() #tidy up the figure 
plt.savefig("world_population_updated.png", dpi=150) #save the figure

# %% [markdown]
# ### Combining geodata and non-geographic data

# %% [markdown]
# Let's combine our world map with some university ranking data. First we load the university ranking data we have been working on over the past two weeks.

# %%
ranking = pd.read_csv("../01_day/times_university_data.csv", sep=",")

# %% [markdown]
# Remember that the "world_rank" column was "object" type because there are rankings like "250-300" included. Let's transfer that column to numeric and drop the observations which we cannot transfer.

# %%
ranking["world_rank"]
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#          ...
# 2598    601-800
# 2599    601-800
# 2600    601-800
# 2601    601-800
# 2602    601-800
# Name: world_rank, Length: 2603, dtype: object

# %%
ranking["world_rank"] = pd.to_numeric(ranking["world_rank"], errors="coerce")

# %% [markdown]
# Let's select only the worlds top 100 universities in 2016.

# %%
top100 = ranking[(ranking["year"] == 2016) & (ranking["world_rank"] <= 100)]

# %% [markdown]
# About a third of the top 100 universities are from the USA.

# %%
country_counts = top100["country"].value_counts()
country_counts
# Out:
# United States of America    30
# United Kingdom              14
# Germany                      7
# Netherlands                  5
# Canada                       3
# Australia                    3
# Singapore                    2
# Switzerland                  2
# Sweden                       2
# South Korea                  1
# Japan                        1
# Hong Kong                    1
# Belgium                      1
# China                        1
# France                       1
# Name: country, dtype: int64

# %% [markdown]
# Let's use pandas ```groupby(by=[])``` method to group our dataframe by countries and then calculate the mean "citations" of the countries' universities in the top 100.

# %%
mean_top100_citations = top100.groupby(by=["country"])["citations"].mean()
mean_top100_citations
# Out:
# country
# Australia                  77.400
# Belgium                    87.300
# Canada                     87.100
# China                      69.100
# France                     87.100
# Germany                    78.229
# Hong Kong                  82.600
# Japan                      60.900
# Netherlands                88.060
# Singapore                  82.500
# South Korea                50.000
# Sweden                     86.550
# Switzerland                92.850
# United Kingdom             91.050
# United States of America   95.707
# Name: citations, dtype: float64

# %% [markdown]
# Now we can merge our world_map geopandas dataframe with the two Pandas series (remember, those are like single column dataframes).

# %%
world_map = world_map.merge(country_counts, how="left", left_on="sovereignt", right_index=True)
world_map = world_map.merge(mean_top100_citations, how="left", left_on="sovereignt", right_index=True)

# %% [markdown]
# And now we can use these two new columns for some fresh new maps.

# %%
fig, axes = plt.subplots(2,1, figsize=(20,20))

# number of top 100 universities map
world_map.plot(figsize=(20,20), column="country", scheme="UserDefined", classification_kwds={'bins':[1, 10, 20, 30]}, legend=True, missing_kwds={'color': 'lightgrey', "label": "No top 100 universities"}, ax=axes[0])
axes[0].set_axis_off()
axes[0].set_title("Number of Universities in Top 100",fontdict={"fontsize":20})

# mean citations map
world_map.plot(figsize=(20,20), column="citations", scheme="NaturalBreaks", k=5, legend=True, missing_kwds={'color': 'lightgrey', "label": "No top 100 universities"}, ax=axes[1])
axes[1].set_axis_off()
axes[1].set_title("Mean Citations of Top 100 Universities",fontdict={"fontsize":20})

# Final adjustments
fig.tight_layout() #tidy up the figure 
plt.savefig("dual_map.png", dpi=150) #save the figure

# %% [markdown]
# The number of top 100 universities by population may be something we are interested in.

# %%
world_map["top_ranking_per_1m_pop"] = world_map["country"] / world_map["pop_million"]

# %% [markdown]
# Looking at the descriptive statistics there seems something wrong. The maximum is very large.

# %%
world_map["top_ranking_per_1m_pop"].describe()
# Out:
# count     16.000
# mean     279.507
# std     1114.426
# min        0.001
# 25%        0.069
# 50%        0.119
# 75%        0.272
# max     4458.599
# Name: top_ranking_per_1m_pop, dtype: float64

# %% [markdown]
# When we look at our observations that have a non-null value in the new "top_ranking_per_1m_pop" column, we see that UK, USA, and France appear more than once and have some suspiciously high "top_ranking_per_1m_pop" values.

# %%
world_map[world_map["sovereignt"] == "United States of America"]
# Out:
#     scalerank       featurecla  labelrank                sovereignt sov_a3  \
# 0           1  Admin-0 country          2  United States of America    US1
# 16          1  Admin-0 country          5  United States of America    US1
#
#     adm0_dif  level        type                     admin adm0_a3  geou_dif  \
# 0          1      2     Country  United States of America     USA         0
# 16         1      2  Dependency               Puerto Rico     PRI         0
#
#                      geounit gu_a3  su_dif                   subunit su_a3  \
# 0   United States of America   USA       0  United States of America   USA
# 16               Puerto Rico   PRI       0               Puerto Rico   PRI
#
#     brk_diff           name      name_long brk_a3       brk_name brk_group  \
# 0          0  United States  United States    USA  United States      None
# 16         0    Puerto Rico    Puerto Rico    PRI    Puerto Rico      None
#
#     abbrev postal                    formal_en formal_fr  \
# 0   U.S.A.     US     United States of America      None
# 16    P.R.     PR  Commonwealth of Puerto Rico      None
#
#                  note_adm0 note_brk                 name_sort name_alt  \
# 0                     None     None  United States of America     None
# 16  Commonwealth of U.S.A.     None               Puerto Rico     None
#
#     mapcolor7  mapcolor8  mapcolor9  mapcolor13       pop_est   gdp_md_est  \
# 0           4          5          1           1 313973000.000 15094000.000
# 16          4          5          1           1   3971020.000    70230.000
#
#     pop_year  lastcensus  gdp_year                  economy  \
# 0          0        2010         0  1. Developed region: G7
# 16       -99        2010       -99     6. Developing region
#
#                  income_grp  wikipedia fips_10 iso_a2 iso_a3 iso_n3 un_a3  \
# 0      1. High income: OECD          0    None     US    USA    840   840
# 16  2. High income: nonOECD        -99    None     PR    PRI    630   630
#
#    wb_a2 wb_a3  woe_id adm0_a3_is adm0_a3_us  adm0_a3_un  adm0_a3_wb  \
# 0     US   USA     -99        USA        USA         -99         -99
# 16    PR   PRI     -99        PRI        PRI         -99         -99
#
#         continent region_un         subregion                  region_wb  \
# 0   North America  Americas  Northern America              North America
# 16  North America  Americas         Caribbean  Latin America & Caribbean
#
#     name_len  long_len  abbrev_len  tiny  homepart     filename  \
# 0         13        13           6   -99         1  USA.geojson
# 16        11        11           4   -99       -99  PRI.geojson
#
#                                              geometry  pop_million  country  \
# 0   MULTIPOLYGON (((-155.54211 19.08348, -155.6881...      313.973   30.000
# 16  POLYGON ((-66.28243 18.51476, -65.77130 18.426...        3.971   30.000
#
#     citations  top_ranking_per_1m_pop
# 0      95.707                   0.096
# 16     95.707                   7.555

# %%
world_map[world_map["top_ranking_per_1m_pop"].notnull()][["sovereignt", "pop_million", "top_ranking_per_1m_pop"]]
# Out:
#                    sovereignt  pop_million  top_ranking_per_1m_pop
# 0    United States of America      313.973                   0.096
# 1                      Canada       33.487                   0.090
# 16   United States of America        3.971                   7.555
# 24             United Kingdom        0.003                4458.599
# 37                      China     1338.613                   0.001
# 45                      Japan      127.079                   0.008
# 52                South Korea       48.509                   0.021
# 120                 Australia       21.263                   0.141
# 123                    France        0.227                   4.397
# 136                   Germany       82.330                   0.085
# 138                   Belgium       10.414                   0.096
# 143               Switzerland        7.604                   0.263
# 149                    France       64.058                   0.016
# 152            United Kingdom       62.262                   0.225
# 166               Netherlands       16.716                   0.299
# 171                    Sweden        9.060                   0.221

# %% [markdown]
# It turns out that, for the example of UK, the Falkland Islands are a separat "Dependency" in the "type" column.

# %%
world_map[world_map["sovereignt"] == "United Kingdom"]
# Out:
#      scalerank       featurecla  labelrank      sovereignt sov_a3  adm0_dif  \
# 24           1  Admin-0 country          5  United Kingdom    GB1         1
# 152          1  Admin-0 country          2  United Kingdom    GB1         1
#
#      level        type             admin adm0_a3  geou_dif           geounit  \
# 24       2  Dependency  Falkland Islands     FLK         0  Falkland Islands
# 152      2     Country    United Kingdom     GBR         0    United Kingdom
#
#     gu_a3  su_dif           subunit su_a3  brk_diff            name  \
# 24    FLK       0  Falkland Islands   FLK         1    Falkland Is.
# 152   GBR       0    United Kingdom   GBR         0  United Kingdom
#
#             name_long brk_a3        brk_name brk_group    abbrev postal  \
# 24   Falkland Islands    B12    Falkland Is.      None  Flk. Is.     FK
# 152    United Kingdom    GBR  United Kingdom      None      U.K.     GB
#
#                                              formal_en formal_fr note_adm0  \
# 24                                    Falkland Islands      None      U.K.
# 152  United Kingdom of Great Britain and Northern I...      None      None
#
#                                  note_brk         name_sort        name_alt  \
# 24   Admin. by U.K.; Claimed by Argentina  Falkland Islands  Islas Malvinas
# 152                                  None    United Kingdom            None
#
#      mapcolor7  mapcolor8  mapcolor9  mapcolor13      pop_est  gdp_md_est  \
# 24           6          6          6           3     3140.000     105.100
# 152          6          6          6           3 62262000.000 1977704.000
#
#      pop_year  lastcensus  gdp_year                     economy  \
# 24        -99         -99       -99  2. Developed region: nonG7
# 152         0        2011      2009     1. Developed region: G7
#
#                income_grp  wikipedia fips_10 iso_a2 iso_a3 iso_n3 un_a3 wb_a2  \
# 24   1. High income: OECD        -99    None     FK    FLK    238   238   -99
# 152  1. High income: OECD        -99    None     GB    GBR    826   826    GB
#
#     wb_a3  woe_id adm0_a3_is adm0_a3_us  adm0_a3_un  adm0_a3_wb  \
# 24    -99     -99        FLK        FLK         -99         -99
# 152   GBR     -99        GBR        GBR         -99         -99
#
#          continent region_un        subregion                  region_wb  \
# 24   South America  Americas    South America  Latin America & Caribbean
# 152         Europe    Europe  Northern Europe      Europe & Central Asia
#
#      name_len  long_len  abbrev_len  tiny  homepart     filename  \
# 24         12        16           8   -99       -99  FLK.geojson
# 152        14        14           4   -99         1  GBR.geojson
#
#                                               geometry  pop_million  country  \
# 24   POLYGON ((-61.20000 -51.85000, -60.00000 -51.2...        0.003   14.000
# 152  MULTIPOLYGON (((-5.66195 54.55460, -6.19788 53...       62.262   14.000
#
#      citations  top_ranking_per_1m_pop
# 24      91.050                4458.599
# 152     91.050                   0.225

# %%
world_map["type"].value_counts()
# Out:
# Sovereign country    159
# Country               10
# Dependency             3
# Indeterminate          2
# Disputed               1
# Name: type, dtype: int64

# %% [markdown]
# So let's recalculate the "top_ranking_per_1m_pop" column in a separat geopandas dataframe which includes "country" and "Sovereign country" types only (no "Dependency" and the like)

# %%
del(world_map["top_ranking_per_1m_pop"]) # delete wrong column in original dataframe

world_map_selection = world_map[world_map["type"].isin(["Sovereign country", "Country"])]
world_map_selection["top_ranking_per_1m_pop"] = world_map_selection["country"] / world_map_selection["pop_million"]

# %% [markdown]
# Now it makes more sense! We can actually see that smaller countries like the Netherlands and Switzerland outperform the USA for example. Both have about three times the top 100 universities per million inhabitants than the US.

# %%
world_map_selection[world_map_selection["top_ranking_per_1m_pop"].notnull()][["sovereignt", "top_ranking_per_1m_pop"]].sort_values(by=["top_ranking_per_1m_pop"], ascending=False)
# Out:
#                    sovereignt  top_ranking_per_1m_pop
# 166               Netherlands                   0.299
# 143               Switzerland                   0.263
# 152            United Kingdom                   0.225
# 171                    Sweden                   0.221
# 120                 Australia                   0.141
# 138                   Belgium                   0.096
# 0    United States of America                   0.096
# 1                      Canada                   0.090
# 136                   Germany                   0.085
# 52                South Korea                   0.021
# 149                    France                   0.016
# 45                      Japan                   0.008
# 37                      China                   0.001

# %%
world_map_selection.plot(figsize=(30,30), column="top_ranking_per_1m_pop", scheme="NaturalBreaks", k=5, legend=True, missing_kwds={'color': 'lightgrey', "label": "No top 100 universities"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Geocoding

# %% [markdown]
# The last thing we want to do today is to *geocode* the locations of all universities in Germany that are included in the ranking. Geocoding describes the process where you transform the textual description of a location (e.g. a postal address) to a geographic object with a defined position on the surface of the earth. Most of you do it on a daily basis when you use the search in Google Maps or Apple Maps on your smartphone.

# %% [markdown]
# Let's first extract the German universities and put them into a separat dataframe.

# %%
german_universities = ranking[(ranking["country"] == "Germany") & (ranking["year"] == 2016)]
german_universities.head(5)
# Out:
#       world_rank                 university_name  country  teaching  \
# 1831      29.000                      LMU Munich  Germany    70.500
# 1839      37.000           Heidelberg University  Germany    68.800
# 1851      49.000   Humboldt University of Berlin  Germany    63.700
# 1855      53.000  Technical University of Munich  Germany    61.000
# 1874      72.000       Free University of Berlin  Germany    57.900
#
#      international  research  citations income total_score num_students  \
# 1831          62.8    77.400     85.700  100.0        77.3       35,691
# 1839          62.8    69.600     88.200   68.2        74.4       28,881
# 1851          62.6    77.000     73.600   36.1        69.9       29,987
# 1855          63.8    66.000     80.100   99.2        69.4       35,565
# 1874          69.2    72.200     60.200   35.1        63.2       33,062
#
#       student_staff_ratio international_students female_male_ratio  year
# 1831               15.500                    13%           62 : 38  2016
# 1839               24.500                    17%           55 : 45  2016
# 1851               52.500                    16%               NaN  2016
# 1855               31.500                    20%           33 : 67  2016
# 1874               39.300                    20%           58 : 42  2016

# %% [markdown]
# There is not much location information included. But we can try to geocode the universties using their name (which often includes the city) and the "country" column.

# %%
german_universities["search_string"] = german_universities["university_name"] + " " + german_universities["country"]
german_universities.head(5)
# Out:
#       world_rank                 university_name  country  teaching  \
# 1831      29.000                      LMU Munich  Germany    70.500
# 1839      37.000           Heidelberg University  Germany    68.800
# 1851      49.000   Humboldt University of Berlin  Germany    63.700
# 1855      53.000  Technical University of Munich  Germany    61.000
# 1874      72.000       Free University of Berlin  Germany    57.900
#
#      international  research  citations income total_score num_students  \
# 1831          62.8    77.400     85.700  100.0        77.3       35,691
# 1839          62.8    69.600     88.200   68.2        74.4       28,881
# 1851          62.6    77.000     73.600   36.1        69.9       29,987
# 1855          63.8    66.000     80.100   99.2        69.4       35,565
# 1874          69.2    72.200     60.200   35.1        63.2       33,062
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 1831               15.500                    13%           62 : 38  2016
# 1839               24.500                    17%           55 : 45  2016
# 1851               52.500                    16%               NaN  2016
# 1855               31.500                    20%           33 : 67  2016
# 1874               39.300                    20%           58 : 42  2016
#
#                                search_string
# 1831                      LMU Munich Germany
# 1839           Heidelberg University Germany
# 1851   Humboldt University of Berlin Germany
# 1855  Technical University of Munich Germany
# 1874       Free University of Berlin Germany

# %% [markdown]
# For the actual geocoding, we use a Python package called Geocoder. Let's install it using pip.

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\jan\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: future in c:\users\jan\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in c:\users\jan\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: six in c:\users\jan\anaconda3\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in c:\users\jan\appdata\roaming\python\python37\site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: ratelim in c:\users\jan\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\jan\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jan\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jan\anaconda3\lib\site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jan\anaconda3\lib\site-packages (from requests->geocoder) (1.25.8)
# Requirement already satisfied: decorator in c:\users\jan\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.1)

# %% [markdown]
# Geocoding with the Geocoder package is super easy. There are several geocoding services you may use. Some of them will be familiar to you. Some require you to create an account before you can use them (you have to pass your login information together with the geocoding request then) and all of them will prevent you from geocoding thousands of observations (for that you usually have to pay).
#
# For now we will use the ESRI arcgis geocoder. Check out the different geocoding providers here: https://geocoder.readthedocs.io/

# %%
import geocoder

geocoding_results = geocoder.arcgis('Darmstadt, Germany')

# %% [markdown]
# When we have a look at the results, we can see that the geocoding worked (```[OK]```) and "Darmstadt, Hessen, Deutschland" has been found as the correct location.

# %%
geocoding_results
# Out:
# <[OK] Arcgis - Geocode [Darmstadt, Hessen]>

# %% [markdown]
# Actually Geocoder will return us a json file with a lot of information

# %%
geocoding_results.json
# Out:
# {'address': 'Darmstadt, Hessen',
#  'bbox': {'northeast': [49.95964000000005, 8.737130000000047],
#   'southwest': [49.78564000000004, 8.563130000000047]},
#  'confidence': 2,
#  'lat': 49.87264000000005,
#  'lng': 8.650130000000047,
#  'ok': True,
#  'quality': 'Locality',
#  'raw': {'name': 'Darmstadt, Hessen',
#   'extent': {'xmin': 8.563130000000047,
#    'ymin': 49.78564000000004,
#    'xmax': 8.737130000000047,
#    'ymax': 49.95964000000005},
#   'feature': {'geometry': {'x': 8.650130000000047, 'y': 49.87264000000005},
#    'attributes': {'Score': 100, 'Addr_Type': 'Locality'}}},
#  'score': 100,
#  'status': 'OK'}

# %% [markdown]
# Compare that to the results of a query for a more specific location.

# %%
geocoder.arcgis('Hochschule Darmstadt D-19, Darmstadt, Deutschland').json
# Out:
# {'address': 'Hochschulstraße, 64289, Darmstadt, Hessen',
#  'bbox': {'northeast': [49.87811094614031, 8.65657627399592],
#   'southwest': [49.876110946140315, 8.654576273995922]},
#  'confidence': 9,
#  'lat': 49.87711094614031,
#  'lng': 8.655576273995921,
#  'ok': True,
#  'quality': 'StreetName',
#  'raw': {'name': 'Hochschulstraße, 64289, Darmstadt, Hessen',
#   'extent': {'xmin': 8.654576273995922,
#    'ymin': 49.876110946140315,
#    'xmax': 8.65657627399592,
#    'ymax': 49.87811094614031},
#   'feature': {'geometry': {'x': 8.655576273995921, 'y': 49.87711094614031},
#    'attributes': {'Score': 92.16, 'Addr_Type': 'StreetName'}}},
#  'score': 92.16,
#  'status': 'OK'}

# %% [markdown]
# The information we are actually interested in are *longitute* and *latitude* (lon and lat) which define the postion of our result on the surface of the earth -->
# https://en.wikipedia.org/wiki/Geographic_coordinate_system
#
# We can get that information directly from the geocoding results using the ```latlng``` method.

# %%
geocoding_results.latlng
# Out:
# [49.87264000000005, 8.650130000000047]

# %% [markdown]
# So let's create a new column in our German universities dataframe with the lon and lat of the universities by using the ```apply(lambda x:)``` method and passing the "search_string" we have created for each university.

# %%
german_universities["lonlat"] = german_universities["search_string"].apply(lambda x: geocoder.arcgis(x).latlng)

# %% [markdown]
# Okay, seems like all our universities now have a filled "lonlat" column.

# %%
german_universities.head(1)
# Out:
#       world_rank university_name  country  teaching international  research  \
# 1831      29.000      LMU Munich  Germany    70.500          62.8    77.400
#
#       citations income total_score num_students  student_staff_ratio  \
# 1831     85.700  100.0        77.3       35,691               15.500
#
#      international_students female_male_ratio  year       search_string  \
# 1831                    13%           62 : 38  2016  LMU Munich Germany
#
#                                         lonlat
# 1831  [48.111330000000066, 11.469220000000064]

# %% [markdown]
# Let's split the longitute and latitude information into two separat columns.

# %%
german_universities["lat"] = german_universities["lonlat"].apply(lambda x: x[0])
german_universities["lon"] = german_universities["lonlat"].apply(lambda x: x[1])

# %%
german_universities.head(2)
# Out:
#       world_rank        university_name  country  teaching international  \
# 1831      29.000             LMU Munich  Germany    70.500          62.8
# 1839      37.000  Heidelberg University  Germany    68.800          62.8
#
#       research  citations income total_score num_students  \
# 1831    77.400     85.700  100.0        77.3       35,691
# 1839    69.600     88.200   68.2        74.4       28,881
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 1831               15.500                    13%           62 : 38  2016
# 1839               24.500                    17%           55 : 45  2016
#
#                       search_string                                    lonlat  \
# 1831             LMU Munich Germany  [48.111330000000066, 11.469220000000064]
# 1839  Heidelberg University Germany   [49.416300000000035, 8.675020000000075]
#
#         lat    lon
# 1831 48.111 11.469
# 1839 49.416  8.675

# %% [markdown]
# Now we can use geopandas to transfer our pandas dataframe into a geodataframe by telling it to generate the ```geometry=points_from_xy()``` from the columns that store the longitute and latitute values.

# %%
german_universities = gpd.GeoDataFrame(german_universities, geometry=gpd.points_from_xy(german_universities["lon"], german_universities["lat"]))

# %%
german_universities.head(2)
# Out:
#       world_rank        university_name  country  teaching international  \
# 1831      29.000             LMU Munich  Germany    70.500          62.8
# 1839      37.000  Heidelberg University  Germany    68.800          62.8
#
#       research  citations income total_score num_students  \
# 1831    77.400     85.700  100.0        77.3       35,691
# 1839    69.600     88.200   68.2        74.4       28,881
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 1831               15.500                    13%           62 : 38  2016
# 1839               24.500                    17%           55 : 45  2016
#
#                       search_string                                    lonlat  \
# 1831             LMU Munich Germany  [48.111330000000066, 11.469220000000064]
# 1839  Heidelberg University Germany   [49.416300000000035, 8.675020000000075]
#
#         lat    lon                   geometry
# 1831 48.111 11.469  POINT (11.46922 48.11133)
# 1839 49.416  8.675   POINT (8.67502 49.41630)

# %%
german_universities.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we can plot both geodataframes within the same subplot by passing the subplot's axis ```ax=ax``` and by defining the order of the two layers using ```zorder=```. However we already saw above that the shape of Germany is not very nice because we are using a low resolution map which is inteneded for global maps. So first we load a high resolution map of europe.

# %%
europe_map = gpd.read_file("europe_map.json")

# %%
europe_map[europe_map["sovereignt"] == "Germany"].plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

europe_map[europe_map["sovereignt"] == "Germany"].plot(ax=ax, zorder=1, color="lightblue")
points = german_universities.plot(ax=ax, zorder=2, column="world_rank", scheme="NaturalBreaks", legend=True, missing_kwds={'color': 'white', "label": "Ranking worse than 200"})
ax.set_axis_off()
ax.set_title("Ranked Universities in Germany", fontdict={"fontsize":20})

# Final adjustments
fig.tight_layout() #tidy up the figure 
plt.savefig("ranked_german_universities.png", dpi=150) #save the figure
